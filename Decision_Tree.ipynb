# %% [markdown]
# <a href="https://colab.research.google.com/github/alvinadar/Decision-Tree/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Classification Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder#helpt to convert non numerical values in a dataset into a numerical values
from sklearn.metrics import accuracy_score #Model evaluation for classification

# %%
# Data
data = {
    'Plays Sports': ['Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No'],
    'Drinks Coffee': ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No'],
    'Age': [7, 12, 18, 35, 38, 50, 83],
    'Enjoys Hiking': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No']
}

# Convert to DataFrame
import pandas as pd
df = pd.DataFrame(data)

df
# Out:
#   Plays Sports Drinks Coffee  Age Enjoys Hiking
# 0          Yes           Yes    7            No
# 1          Yes            No   12            No
# 2           No           Yes   18           Yes
# 3           No           Yes   35           Yes
# 4          Yes           Yes   38           Yes
# 5          Yes            No   50            No
# 6           No            No   83            No

# %%
#Convert non numerical values to numerical values

label_encoder = {}#Empty dictionary to store all the encoding infomation

# changing categorical values (Yes/No) into (1/0)

# why we do it?
# 1. ML models need numbers (most ML algorithms cant handle non-numeric data directly)
# 2. Efficiency in processing (simpligies data processing)

for columns in ['Plays Sports','Drinks Coffee','Enjoys Hiking']:
  le = LabelEncoder()
  df[columns] = le.fit_transform(df[columns])
  label_encoder[columns] = le

print(label_encoder)
# Out:
# {'Plays Sports': LabelEncoder(), 'Drinks Coffee': LabelEncoder(), 'Enjoys Hiking': LabelEncoder()}

# %%
# Features (X) and target (y)

X = df[['Plays Sports','Drinks Coffee','Age']]
y = df['Enjoys Hiking']

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree#Show the decision tree created by Sklearn

#Plot the decision tree
plt.figure(figsize=(12,8))
plot_tree(clf,
          feature_names=['Plays Sports','Drinks Coffee','Age'],
          class_names=label_encoder['Enjoys Hiking'].classes_,
          filled=True,
          fontsize=12
)

plt.show()
